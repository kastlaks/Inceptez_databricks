# %% [markdown]
# # All About Markdown

# %% [markdown]
# ## welcome to _Inceptez_
# ![Iz Logo](https://fplogoimages.withfloats.com/actual/68009c3a43430aff8a30419d.png)
#
#
#
# Topic **Markdown**
# `for i in range(10): print(i)`
#
# visit [inceptez ](https://inceptezlabs.com/aibi)

# %% [markdown]
# ## 1. Basic Python Types
#
# 1. int
# 2. str
# 3. float
#
#
# - list
# - list2

# %%
num=10
print(type(num))

# %%
dbutils.help()
