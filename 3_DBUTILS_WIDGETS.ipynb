# %% [markdown]
# # All About DBUTILS

# %% [markdown]
# dbutils = Databricks untility
#
# helper module to intract with DBFS , widgets , run notbook /jobs , manage secrets

# %%
dbutils.help()

# %% [markdown]
# ## Dbutils Fs

# %%
dbutils.fs.help()

# %%
dbutils.widgets.help()

# %%
dbutils.widgets.text("country",'')

# %%
country_name = dbutils.widgets.get("country")
print(country_name) 
print(f"fetching {country_name}  data from db ")

# %%
dbutils.widgets.text("range_value","5")

# %%
int_range=int(dbutils.widgets.get("range_value"))
print(int_range)
for i in range(int_range):
  print(i)

# %%
dbutils.widgets.dropdown("Gender","select",["select","Male","Female"])

# %%
dbutils.widgets.combobox("Country","India",["India","USA","UK"])

# %%
country=dbutils.widgets.get("Country")
print(f"Selected {country}")

# %%
dbutils.widgets.text("FirstName","test")

# %%
print(dbutils.widgets.get("FirstName"))

# %%
dbutils.widgets.multiselect("Groceries Items","Chocolate",["Chocolate","Biscuit","Water"])
Items=dbutils.widgets.get("Groceries Items")
print(Items)
print(type(Items))
print(Items[:11:-1])
print(Items[11:-1])

# %%
gender=dbutils.widgets.get("Gender")
gender=dbutils.widgets.get("Groceries Items")
genderall = dbutils.widgets.getAll()
print(gender)
print(genderall)

# %%
dbutils.widgets.removeAll()
